# %% [markdown]
# <a href="https://colab.research.google.com/github/gmiserani/fisica-computacional/blob/main/FISICA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mapa Logístico

# %%
#y = r*yn*(1-yn)

# %%
import matplotlib.pyplot as plt

# %%
def tarefa(y0, r, n):
  y1 = r*y0*(1-y0)
  array = []
  x = []
  x.append(1)
  x.append(2)
  array.append(y0)
  array.append(y1)
  num = 3
  for i in range(n):
    yn = y1
    y = r*yn*(1-yn)
    array.append(y)
    x.append(num)
    num = num + 1
    y1 = y
  return array, num

# %%
primeiro, x = tarefa(0.5, 0.5, 50)
print(primeiro)
# Out:
# [0.5, 0.125, 0.0546875, 0.025848388671875, 0.012590124737471342, 0.006215806748283127, 0.0030885852473755623, 0.0015395229442726282, 0.0007685764066883431, 0.00038399284849771257, 0.0001919226989950076, 9.594293233630902e-05, 4.7966863645021866e-05, 2.3982281412506963e-05, 1.1990853131342606e-05, 5.9953546753918944e-06, 2.9976593655571054e-06, 1.4988251897977167e-06, 7.494114716603835e-07, 3.747054550214148e-07, 1.873526573086184e-07, 9.36763111038001e-08, 4.683815116427442e-08, 2.341907448523101e-08, 1.170953696838898e-08, 5.854768415637862e-09, 2.9273841906797743e-09, 1.463692091055098e-09, 7.318460444563517e-10, 3.6592302196037656e-10, 1.8296151091323845e-10, 9.148075543988177e-11, 4.574037771575652e-11, 2.2870188856832168e-11, 1.1435094428154562e-11, 5.717547214011901e-12, 2.858773606989605e-12, 1.4293868034907161e-12, 7.146934017443365e-13, 3.573467008719129e-13, 1.7867335043589258e-13, 8.933667521793034e-14, 4.466833760896117e-14, 2.233416880447959e-14, 1.1167084402239545e-14, 
# ...

# %%
plt.plot(primeiro)

# %%
r2, x = tarefa(0.5, 2.5, 50)
r3, x1 = tarefa(0.5, 3.1, 50)
r4, x2 = tarefa(0.5, 3.5, 50)
r5, x3 = tarefa(0.5, 3.7, 50)

#com a modificacao do r, tendo y0 constante, é perceptível

# %%
plt.plot(r2)
# Out:
# Error in callback <function flush_figures at 0x7fc1b83360d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
plt.plot(r3)

# %%
plt.plot(r4)

# %%
plt.plot(r5)

# %%
#def tarefa(y0, r, n):
#y0 = 0.25, todos os r
y1r0, x = tarefa(0.25, 0.5, 50)
y1r1, x = tarefa(0.25, 2.5, 50)
y1r2, x = tarefa(0.25, 3.1, 50)
y1r3, x = tarefa(0.25, 3.5, 50)
y1r4, x = tarefa(0.25, 3.7, 50)

#y0 = 0.5, todos os r
y2r0, x = tarefa(0.5, 0.5, 50)
y2r1, x = tarefa(0.5, 2.5, 50)
y2r2, x = tarefa(0.5, 3.1, 50)
y2r3, x = tarefa(0.5, 3.5, 50)
y2r4, x = tarefa(0.5, 3.7, 50)

#y0 = 0.75, todos os r
y3r0, x = tarefa(0.75, 0.5, 50)
y3r1, x = tarefa(0.75, 2.5, 50)
y3r2, x = tarefa(0.75, 3.1, 50)
y3r3, x = tarefa(0.75, 3.5, 50)
y3r4, x = tarefa(0.75, 3.7, 50)

plt.plot(y1r0)

# %%
plt.plot(y1r1)

# %%
plt.plot(y1r2)

# %%
plt.plot(y1r3)

# %%
plt.plot(y1r4)

# %%
plt.plot(y2r0)

# %%
plt.plot(y2r1)

# %%
plt.plot(y2r2)

# %%
plt.plot(y2r3)

# %%
plt.plot(y2r4)

# %%
plt.plot(y3r0)

# %%
plt.plot(y3r1)

# %%
plt.plot(y3r2)

# %%
plt.plot(y3r3)

# %%
plt.plot(y3r4)

# %%
#y0 = 0.25, todos os r
y1r0, x = tarefa(0.5, 0.5, 50)
y1r1, x = tarefa(0.5, 2.5, 50)
y1r2, x = tarefa(0.5, 3.1, 50)
y1r3, x = tarefa(0.5, 3.5, 50)
y1r4, x = tarefa(0.5, 3.7, 50)

#y0 = 0.5, todos os r
y2r0, x = tarefa(0.501, 0.5, 50)
y2r1, x = tarefa(0.501, 2.5, 50)
y2r2, x = tarefa(0.501, 3.1, 50)
y2r3, x = tarefa(0.501, 3.5, 50)
y2r4, x = tarefa(0.501, 3.7, 50)

#y0 = 0.75, todos os r
y3r0, x = tarefa(0.5001, 0.5, 50)
y3r1, x = tarefa(0.5001, 2.5, 50)
y3r2, x = tarefa(0.5001, 3.1, 50)
y3r3, x = tarefa(0.5001, 3.5, 50)
y3r4, x = tarefa(0.5001, 3.7, 50)

# %%
plt.plot(y1r0)

# %%
plt.plot(y1r1)

# %%
plt.plot(y1r2)

# %%
plt.plot(y1r3)

# %%
plt.plot(y1r4)

# %%
plt.plot(y2r0)

# %%
plt.plot(y2r1)

# %%
plt.plot(y2r2)

# %%
plt.plot(y2r3)

# %%
plt.plot(y2r4)

# %%
plt.plot(y3r0)

# %%
plt.plot(y3r1)

# %%
plt.plot(y3r2)

# %%
plt.plot(y3r3)

# %%
plt.plot(y3r4)

# %%
#def tarefa(y0, r, n):
import numpy as np
r_espacados = np.linspace(10^-5, 4, num = 10000)
array = []
for i in r_espacados:
  y, x = tarefa(0.5, i, 1000)
  array.append(y[900:-1])
plt.plot(r_espacados, array)
# Out:
# <ipython-input-56-0c57ee584245>:12: RuntimeWarning: overflow encountered in double_scalars
#   y = r*yn*(1-yn)
# ...

# %%
r_espacados = np.linspace(3.7, 3.9, num = 10000)
array = []
for i in r_espacados:
  y,x = tarefa(0.5, i, 1000)
  array.append(y[900:-1])
plt.plot(r_espacados, array)

# %% [markdown]
# se lambda for positivo tem caos -> expoente de Iacmov
